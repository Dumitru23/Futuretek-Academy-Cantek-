# %%
list1=[1, 2, 3, 4, 5]
print(type(list1))
# Out:
# <class 'list'>

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 5

# %%
list2=[2,3,4,5,6,7]

# %%
print(list2)
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
len(list2)
# Out:
# 6

# %%
def find_value_in_tuple(val, tup):
    try:
        tup.index(val)
        return tup.index(val)
    except Exception:
        return "sorry val is not in tuple"
    
    find_value_in_tuple(2, tuple1)

# %%
tuple1 = (1, 2, 6, 8)

# %%
  find_value_in_tuple(2, tuple1)
# Out:
# 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_Country = pd.read_csv("Country_data.csv")
df_Country.head(10)
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
# 5      Armenia                 0.094               0.102             0.024
# 6    Australia                 0.980               0.860             0.807
# 7      Austria                 0.949               0.843             0.728
# 8   Azerbaijan                 0.094               0.102             0.024
# 9      Bahrain                 0.449               0.024               NaN
#
#     Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0         NaN                        5.506573                6.393604
# ...

# %%
df_Country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 43 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
df_Country.describe()
# Out:
#        indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# count            177.000000          177.000000        175.000000
# mean               0.433633            0.271169          0.205794
# std                0.308818            0.255504          0.239538
# min                0.003000            0.010000          0.011000
# 25%                0.135000            0.102000          0.044500
# 50%                0.373000            0.169000          0.096000
# 75%                0.682000            0.322000          0.244000
# max                0.992000            0.905000          0.879000
#
#        Economic.Freedom.Summary.Index  Government.consumption  \
# count                      182.000000              182.000000
# mean                         5.497105                6.397742
# std                          0.990792                1.631789
# min                          3.400000                0.050000
# ...

# %%
df_Country.shape
# Out:
# (182, 43)

# %%
df_Country.shape[0]
# Out:
# 182

# %%
df_Country.columns
# Out:
# Index(['Entity', 'indiv_libs_vdem_owid', 'electdem_vdem_owid',
#        'libdem_vdem_owid', 'Countries', 'Economic.Freedom.Summary.Index',
#        'Government.consumption', 'Transfers.and.subsidies',
#        'Government.investment', 'State.ownership.of.assets',
#        'Size.of.Government', 'Judicial.independence', 'Impartial.courts',
#        'Integrity.of.the.legal.system', 'Legal.enforcement.of.contracts',
#        'Gender.Legal.Rights.Adjustment', 'Legal.System...Property.Rights',
#        'Money.growth', 'Standard.deviation.of.inflation',
#        'Inflation..Most.recent.year',
#        'Freedom.to.own.foreign.currency.bank.accounts', 'Sound.Money',
#        'Revenue.from.trade.taxes....of.trade.sector.', 'Tariffs',
#        'Black.market.exchange.rates', 'Financial.Openness', 'Capital.controls',
#        'Controls.of.the.movement.of.capital.and.people',
#        'Freedom.to.trade.Internationally', 'Ownership.of.banks',
#        'Private.sector.credit',
# ...

# %%
df_Country.dtypes
# Out:
# Entity                                                   object
# indiv_libs_vdem_owid                                    float64
# electdem_vdem_owid                                      float64
# libdem_vdem_owid                                        float64
# Countries                                                object
# Economic.Freedom.Summary.Index                          float64
# Government.consumption                                  float64
# Transfers.and.subsidies                                 float64
# Government.investment                                   float64
# State.ownership.of.assets                               float64
# Size.of.Government                                      float64
# Judicial.independence                                   float64
# Impartial.courts                                        float64
# Integrity.of.the.legal.system                           float64
# Legal.enforcement.of.contracts                          float64
# ...

# %%
df_Country.groupby('Regime_type')

# %%
df_grouped=df_Country.groupby('Regime_type')

# %%
df_grouped.describe()
# Out:
#                                indiv_libs_vdem_owid                      \
#                                               count      mean       std
# Regime_type
# Democracy                                      39.0  0.841462  0.204599
# Military rule                                  34.0  0.272853  0.142028
# Monarchy                                       13.0  0.357462  0.190659
# Multi-party authoritarian rule                  6.0  0.609000  0.210711
# Other oligarchy                                 4.0  0.218250  0.216649
# Personalist rule                               20.0  0.390350  0.227198
# Single-party rule                              40.0  0.264850  0.209088
# unknown                                        21.0  0.337333  0.305038
#
#                                                                        \
#                                   min     25%     50%      75%    max
# Regime_type
# Democracy                       0.049  0.7910  0.9090  0.97250  0.992
# ...

# %%
df_grouped=df_Country.groupby('Regime_type')

# %%
df_grouped['Size.of.Government'].describe()
# Out:
#                                 count      mean       std       min       25%  \
# Regime_type
# Democracy                        39.0  6.451795  1.373909  3.770000  5.580000
# Military rule                    34.0  6.529087  1.194814  4.180000  5.789865
# Monarchy                         13.0  6.092708  1.133357  4.580000  5.150000
# Multi-party authoritarian rule    6.0  6.500642  0.950656  5.070000  6.044385
# Other oligarchy                   4.0  6.862838  0.482879  6.380000  6.537500
# Personalist rule                 20.0  6.253288  1.513037  2.020000  5.602500
# Single-party rule                41.0  4.968593  1.333538  2.378599  4.260000
# unknown                          25.0  6.050831  1.080706  3.360000  5.670000
#
#                                      50%       75%       max
# Regime_type
# Democracy                       6.320000  7.495000  9.290000
# Military rule                   6.512366  7.530000  8.770000
# ...

# %%
df_Country.groupby('Regime_type')['Size.of.Government'].describe()
# Out:
#                                 count      mean       std       min       25%  \
# Regime_type
# Democracy                        39.0  6.451795  1.373909  3.770000  5.580000
# Military rule                    34.0  6.529087  1.194814  4.180000  5.789865
# Monarchy                         13.0  6.092708  1.133357  4.580000  5.150000
# Multi-party authoritarian rule    6.0  6.500642  0.950656  5.070000  6.044385
# Other oligarchy                   4.0  6.862838  0.482879  6.380000  6.537500
# Personalist rule                 20.0  6.253288  1.513037  2.020000  5.602500
# Single-party rule                41.0  4.968593  1.333538  2.378599  4.260000
# unknown                          25.0  6.050831  1.080706  3.360000  5.670000
#
#                                      50%       75%       max
# Regime_type
# Democracy                       6.320000  7.495000  9.290000
# Military rule                   6.512366  7.530000  8.770000
# ...

# %%
df_Country['libdem_vdem_owid_nomiss'] = df_Country['libdem_vdem_owid'].fillna(df_Country['libdem_vdem_owid'].mean())

# %%
df_Country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 44 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
df_Country.iloc[3]['libdem_vdem_owid']
# Out:
# 0.035

# %%
type(df_Country.iloc[3]['libdem_vdem_owid'])
# Out:
# numpy.float64

# %%
for i in range(0,182):
    if type(df_Country.iloc[3]['libdem_vdem_owid'])== str:
        print("string")

# %%
data = {'price': [100, 200, 150, 300]}
df = pd.DataFrame(data)
#apply lamda function to calculate discounted price
df['new_price'] = df['price'] * 0.9
df.head()
# Out:
#    price  new_price
# 0    100       90.0
# 1    200      180.0
# 2    150      135.0
# 3    300      270.0

# %%
def transforming():
    if df['A'] >=3:
        return(x*2)
    else:
        return(x+5)

#function1 = lamdda x: x*2
#condition2 = df['A'] >= 3
#function2 = lambda x: x + 5
# Apply a function / Logic based on condition and create a new column
df['C'] = df ['B'].apply(lambda x: transforming x  #x* 2 if f['A'] < 3 else x: x + 5 ])
# Out:
#   Cell In[76], line 5
#     df['C'] = df ['B'].apply(lambda x: x* 2 if f['A'] < 3 else x: x + 5 ])
#                                                                         ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
data = {'A': [1, 2, 3, 4, 5], 'B':[10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
condition1 = df['A'] < 3
function1 = lambda x: x * 2
condition2 = df['A'] >= 3
function2 = lambda x: x + 5

#Apply the funct / logic based on cond and create the new column
df['C'] = np.where(condition1, function1(df['A']), function2(df['B']))

print(df)
# Out:
#    A   B   C
# 0  1  10   2
# 1  2  20   4
# 2  3  30  35
# 3  4  40  45
# 4  5  50  55

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
reshaped_arr = np.reshape(arr, (3, 2))
print(reshaped_arr)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
reshaped_arr = np.reshape(arr, (2, 3))
print(reshaped_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# Transpose an array
arr = np.array([[1, 2, 3], [4, 5, 6]])

transposed_arr = np.transpose(arr)
print(transposed_arr)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr)
transposed_arr = np.transpose(arr)
print(transposed_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
# Split an array into sub-arrays
arr = np.array([1, 2, 3, 4, 5, 6])
sub_arrays = np.split(arr, 3)
print(sub_arrays)
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
# Resize an array
arr = np.array([1, 2, 3])
resized_arr = np.resize(arr, (2, 5))
print(resized_arr)
# Out:
# [[1 2 3 1 2]
#  [3 1 2 3 1]]
