# %%
# Assignment 2 Web-Scrapping
# Some tasks you can automate through the use of web scraping include comparing financial reports, 
# gathering email addresses, 
# statistical research, 
# price comparison, 
# finding job listings and more. 
import requests
from bs4 import BeautifulSoup

# Make the HTTP request
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_in_Europe_by_GDP_(nominal)_per_capita'
# 'https://proxyway.com/guides/best-websites-to-practice-your-web-scraping-skills'
# 'https://ca.finance.yahoo.com/' #'https://en.chessbase.com/'

response = requests.get(url)

# Parse the HTML content with Beautiful Soup
soup = BeautifulSoup(response.content, 'html.parser')

# Remove unwanted elements (script, style, comments, etc.)
for element in soup(['script', 'style', 'comment']):
       element.extract()

# Extract the visible text
text = soup.get_text(separator=' ')

# replace new lines with no space
text = text.replace('\n', ' ')

# Print the extracted text
print(text)
# Out:
#         List of sovereign states in Europe by GDP (nominal) per capita - Wikipedia                                                                             Jump to content                 Main menu             Main menu   move to sidebar   hide        		Navigation 	     Main page Contents Current events Random article About Wikipedia Contact us Donate          		Contribute 	     Help Learn to edit Community portal Recent changes Upload file           Languages     Language links are at the top of the page across from the title.                                         Search                         Search                 Create account Log in             Personal tools             Create account   Log in         Pages for logged out editors  learn more     Contributions Talk                                                       Contents   move to sidebar   hide           (Top)             1 List of sovereign states in Europe by GDP (nominal) per capita 2021                 2 Map of
# ...

# %%
# 2. Scrape HTML Content From a Page
page = requests.get(url)

print(page.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of sovereign states in Europe by GDP (nominal) per capita - Wikipedia</title>
# ...

# %%
# Importing libraries
# Extract all the URLs that are nested within <li> tags using BeautifulSoup
  
# # setting up the URL
# URL = 'https://www.randstad.ca/job-seeker/career-resources/job-search-tips/top-10-highest-paying-jobs-2023/'
  
# # perform get request to the url
reqs = requests.get(url)
  
# # extract all the text that you received from
# the GET request
content = reqs.text
  
# # convert the text to a beautiful soup object
soup = BeautifulSoup(content, 'html.parser')
  
# Empty list to store the output
urls = []
  
# For loop that iterates over all the <li> tags
for h in soup.findAll('li'):
    
    # looking for anchor tag inside the <li>tag
    a = h.find('a')
    try:
        
        # looking for href inside anchor tag
        if 'href' in a.attrs:
            
            # storing the value of href in a separate variable
            url = a.get('href')
              
            # appending the url to the output list
            urls.append(url)
              
    # if the list does not has a anchor tag or an anchor tag
    # does not has a href params we pass
    except:
        pass
  
# print all the urls stored in the urls list
for url in urls:
    print(url)
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /w/index.php?title=Special:CreateAccount&returnto=List+of+sovereign+states+in+Europe+by+GDP+%28nominal%29+per+capita
# /w/index.php?title=Special:UserLogin&returnto=List+of+sovereign+states+in+Europe+by+GDP+%28nominal%29+per+capita
# /w/index.php?title=Special:CreateAccount&returnto=List+of+sovereign+states+in+Europe+by+GDP+%28nominal%29+per+capita
# /w/index.php?title=Special:UserLogin&returnto=List+of+sovereign+states+in+Europe+by+GDP+%28nominal%29+per+capita
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# ...

# %%
# List the Title of the webpage
import pandas as pd
from urllib.parse import urlparse
import numpy as np
import nltk.data
from requests_html import HTMLSession
from urllib import request
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_in_Europe_by_GDP_(nominal)_per_capita'
html = request.urlopen(url).read().decode('utf8')
html[:60]


soup = BeautifulSoup(html, 'html.parser')
title = soup.find('title')

print(title) # Prints the tag
print(title.string) # Prints the tag string content
# Out:
# <title>List of sovereign states in Europe by GDP (nominal) per capita - Wikipedia</title>
# List of sovereign states in Europe by GDP (nominal) per capita - Wikipedia

# %%
# Get all HTML tags with BeautifulSoup

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content using any parser
soup = BeautifulSoup(html_content, "html.parser")
  
# Display HTML tags
[tag.name for tag in soup.find_all()]
# Out:
# ['html',
#  'head',
#  'meta',
#  'title',
#  'script',
#  'script',
#  'link',
#  'script',
#  'meta',
#  'link',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'body',
#  'a',
#  'div',
#  'header',
#  'div',
#  'nav',
#  'div',
#  'input',
#  'label',
#  'span',
#  'span',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'button',
#  'button',
#  'div',
#  'div',
#  'div',
#  'ul',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'div',
#  'div',
#  'div',
#  'ul',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
#  'li',
#  'a',
#  'span',
# ...

# %%
#Get all the links in the page along with its attributes, such as href, title, and its inner Text.
for link in soup.find_all("a"):
    print("Inner Text: {}".format(link.text))
    print("Title: {}".format(link.get("title")))
    print("href: {}".format(link.get("href")))
# Out:
# Inner Text: Jump to content
# Title: None
# href: #bodyContent
# Inner Text: Main page
# Title: Visit the main page [z]
# href: /wiki/Main_Page
# Inner Text: Contents
# Title: Guides to browsing Wikipedia
# href: /wiki/Wikipedia:Contents
# Inner Text: Current events
# Title: Articles related to current events
# href: /wiki/Portal:Current_events
# Inner Text: Random article
# Title: Visit a randomly selected article [x]
# href: /wiki/Special:Random
# Inner Text: About Wikipedia
# Title: Learn about Wikipedia and how it works
# href: /wiki/Wikipedia:About
# Inner Text: Contact us
# Title: How to contact Wikipedia
# href: //en.wikipedia.org/wiki/Wikipedia:Contact_us
# Inner Text: Donate
# Title: Support us by donating to the Wikimedia Foundation
# href: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Inner Text: Help
# Title: Guidance on how to use and edit Wikipedia
# ...

# %%
# Find all the tables available in web page
tables = soup.findAll("table")

for table in tables:
     if table.findParent("table") is None:
         print(str(table))
# Out:
# <table border="1" class="wikitable sortable static-row-numbers plainrowheaders srn-white-background" style="text-align:right;">
# <caption>Nominal GDP (in US$) per capita by country
# </caption>
# <tbody><tr class="static-row-header" style="text-align:center;vertical-align:bottom;">
# <th>Country
# </th>
# <th>Rank
# </th>
# <th><a class="mw-redirect" href="/wiki/IMF" title="IMF">IMF</a><sup class="reference" id="cite_ref-IMFRank_5-0"><a href="#cite_note-IMFRank-5">[5]</a></sup>
# </th>
# <th style="background: #ddd">Rank
# </th>
# <th><a href="/wiki/World_Bank" title="World Bank">WB</a><sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> 2019
# </th>
# <th>Change
# </th></tr>
# <tr>
# ...

# %%
# Find header content (theads in html) with BeautifulSoup
table = soup.find('table',  attrs={"class": "wikitable"})
# then we can iterate through each row and extract either header or row values:
header = []
rows = []
for i, row in enumerate(table.find_all('tr')):
    if i == 0:
        header = [el.text.strip() for el in row.find_all('th')]
    else:
        rows.append([el.text.strip() for el in row.find_all('td')])

print(header)
# Out:
# ['Country', 'Rank', 'IMF[5]', 'Rank', 'WB[6] 2019', 'Change']

# %%
# Scrape HTML tables easily with Pandas and Python
# in this case I just output first table in an arange view.
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep

df = pd.read_html('https://en.wikipedia.org/wiki/List_of_sovereign_states_in_Europe_by_GDP_(nominal)_per_capita', parse_dates = True)

print(df[0])

#Import data from table to csv file
df[0].to_csv('country1.csv')
# Out:
#                    Country Rank    IMF[5] Rank.1 WB[6] 2019  Change
# 0                  Albania  101    6285.0     94       5353    10.5
# 1         Armenia ㅤㅤㅤ ㅤㅤㅤㅤ  104    4692.0     41       4670     9.5
# 2                  Austria   14   53859.0     13      55060     7.0
# 3                  Belarus   75   10487.0     77       9663    15.5
# 4                  Belgium   18   50103.0     17      46421     6.0
# 5                 Bulgaria   73   11321.0     71       9828     9.7
# 6   Bosnia and Herzegovina   95    7041.0     91       6108     9.3
# 7                  Croatia   54   16247.0     56      14936     8.7
# 8                   Cyprus   28   29551.0     32      27858     7.1
# 9           Czech Republic   37   25732.0     35      23495    10.3
# 10                 Denmark    9   67218.0      8      60170     5.7
# 11                 Estonia   38   26470.0     37      23723    12.9
# 12                 Finland   15   56391.0     14      48783     6.8
# ...

# %%
# Process column Rank, convert from obj to int,  Sort countries by column IMF 
import pandas as pd

df1 = pd.read_csv('country1.csv')

#Eliminate empty cells from table
df1 = df1.dropna()

#Change name of rank into Standing
df1 = df1.rename(columns={ data_import.columns[2]: "Standing" })
df1 = df1.rename(columns={ data_import.columns[3]: "IMF" })

result = df1.dtypes

print("Output:")
print(result)

# Convert single column to int dtype.
df1['Standing'] = df1["Standing"].astype('int')

print(result)

# Sort ascending order
df1.sort_values(
    by=["Standing", "IMF"],
    ascending = True
                )
# Out:
# Output:
# Unnamed: 0      int64
# Country        object
# Standing       object
# IMF           float64
# Rank.1         object
# WB[6] 2019     object
# Change        float64
# dtype: object
# Unnamed: 0      int64
# Country        object
# Standing       object
# IMF           float64
# Rank.1         object
# WB[6] 2019     object
# Change        float64
# dtype: object
#     Unnamed: 0                 Country  Standing       IMF Rank.1 WB[6] 2019  \
# 25          25              Luxembourg         1  138772.0      1     114705
# 42          42             Switzerland         2   94696.0      2      81994
# 31          31                  Norway         3   81995.0      3      75420
# 19          19                 Ireland         4   94556.0      4      78661
# 18          18                 Iceland         6   72231.0      5      66945
# 10          10                 Denmark         9   67218.0      8      60170
# ...

# %%
# Create a bar chart and show the all Countries in descending order ranked by IMF
import matplotlib.pyplot as plt
import pandas as pd
    
x = df1["Country"]
y = df1["IMF"]

plt.figure(figsize = (20, 8), dpi= 200)

#Bar Chart
plt.xlabel('Country',  color = 'green', fontsize = 14)
plt.ylabel('IMF', fontsize = 14, color = 'green')
plt.title('Nominal GDP (in US$) per capita by country based on IMF', fontsize = 14, color = 'red')
#plt.bar(x, y, width = 0.5)

y_pos = range(len(x))
plt.bar(y_pos, y, width = 0.6)

# Rotation of the bars names
plt.xticks(y_pos, x, rotation = 90)

plt.show()

# %%
# Process column WB, convert from obj to int,  Change its name to "World_Bank_2019"
# Sort countries by column IMF 

df2 = pd.read_csv('country1.csv')

#Eliminate empty cells from table
df2 = df1.dropna()

#Change name of rank into Standing
df2 = df2.rename(columns={ data_import.columns[5]: "World_Bank_2019" })

result = df2.dtypes

print("Output:")
print(result)

# Convert single column to int dtype.
df2['World_Bank_2019'] = df2["World_Bank_2019"].astype('int')

# print(result)

# Sort ascending order
df2.sort_values(
    by=["World_Bank_2019"],
    ascending = False
                )
# Out:
# Output:
# Unnamed: 0           int64
# Country             object
# Standing             int32
# IMF                float64
# Rank.1              object
# World_Bank_2019     object
# Change             float64
# dtype: object
#     Unnamed: 0                 Country  Standing       IMF Rank.1  \
# 25          25              Luxembourg         1  138772.0      1
# 42          42             Switzerland         2   94696.0      2
# 19          19                 Ireland         4   94556.0      4
# 31          31                  Norway         3   81995.0      3
# 18          18                 Iceland         6   72231.0      5
# 10          10                 Denmark         9   67218.0      8
# 2            2                 Austria        14   53859.0     13
# 30          30             Netherlands        12   61516.0     12
# 41          41                  Sweden        11   58977.0     10
# 12          12                 Finland        15   56391.0     14
# ...

# %%
# Create a bar chart and show the all Countries in descending order ranked by World_Bank_2019

plt.figure(figsize=(12, 8))
plt.barh(df2['Country'], df2['IMF'])
plt.xlabel('World_Bank_2019')
plt.ylabel('Country')
plt.title('Nominal GDP (in US$) per capita by country in 2021 based by World_Bank_2019')
plt.show()
